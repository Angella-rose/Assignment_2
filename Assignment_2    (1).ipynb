# %%
import pandas as pd
import numpy as np

# %%
pd.__version__
# Out:
# '1.1.3'

# %%
np.__version__
# Out:
# '1.19.2'

# %%
df = pd.read_csv ('WA_Fn-UseC_-HR-Employee-Attrition.csv')
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %%
df['DistanceFromHome']
df['DistanceFromHome'].mean()
# Out:
# 9.19251700680272

# %%
break_down = df [["DistanceFromHome", "JobRole", "Attrition"]]
break_down
# Out:
#       DistanceFromHome                    JobRole Attrition
# 0                    1            Sales Executive       Yes
# 1                    8         Research Scientist        No
# 2                    2      Laboratory Technician       Yes
# 3                    3         Research Scientist        No
# 4                    2      Laboratory Technician        No
# ...                ...                        ...       ...
# 1465                23      Laboratory Technician        No
# 1466                 6  Healthcare Representative        No
# 1467                 4     Manufacturing Director        No
# 1468                 2            Sales Executive        No
# 1469                 8      Laboratory Technician        No
#
# [1470 rows x 3 columns]

# %%
Attrition_count = df['Attrition'].value_counts()
Attrition_count
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
import seaborn as sns
sns.catplot(x="Attrition", y="DistanceFromHome", hue="JobRole", data=df, kind="bar")

# %%
# Let me explain the attrition in terms of resigning due to distance from home and also compare to all their Job roles
 #Most of the Sales Executive, Healthcare Represenatatives and the Human Resources,Research Scientists and Managers resigned due to a long distance from home as compared to Manufacturing Director,Sales Representatives and Research Director.

# %%
# Question 2
compare = df [["MonthlyIncome", "Education", "Attrition"]]
compare
# Out:
#       MonthlyIncome  Education Attrition
# 0              5993          2       Yes
# 1              5130          1        No
# 2              2090          2       Yes
# 3              2909          4        No
# 4              3468          1        No
# ...             ...        ...       ...
# 1465           2571          2        No
# 1466           9991          1        No
# 1467           6142          3        No
# 1468           5390          3        No
# 1469           4404          3        No
#
# [1470 rows x 3 columns]

# %%
compare.mean()
# Out:
# MonthlyIncome    6502.931293
# Education           2.912925
# dtype: float64

# %%
Educated_above_average_monthlyincome = df[df["MonthlyIncome"] > 6503]
Educated_above_average_monthlyincome
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 8      38        No  Travel_Frequently        216  Research & Development
# 15     29        No      Travel_Rarely       1389  Research & Development
# 18     53        No      Travel_Rarely       1219                   Sales
# 22     34        No      Travel_Rarely        419  Research & Development
# 25     53        No      Travel_Rarely       1282  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1453   36        No      Travel_Rarely       1120                   Sales
# 1461   50       Yes      Travel_Rarely        410                   Sales
# 1462   39        No      Travel_Rarely        722                   Sales
# 1463   31        No         Non-Travel        325  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
# Compare average monthly income by education

# 493 educated employees out of 1470 are above the Average_Monthly_Income

# %%
Efficiency = df [["MonthlyIncome", "Attrition"]]
Efficiency
# Out:
#       MonthlyIncome Attrition
# 0              5993       Yes
# 1              5130        No
# 2              2090       Yes
# 3              2909        No
# 4              3468        No
# ...             ...       ...
# 1465           2571        No
# 1466           9991        No
# 1467           6142        No
# 1468           5390        No
# 1469           4404        No
#
# [1470 rows x 2 columns]

# %%
Attrition_count = df['Attrition'].value_counts()
Attrition_count
# Out:
# No     1233
# Yes     237
# Name: Attrition, dtype: int64

# %%
import seaborn as sns
sns.catplot(x="Attrition", y="MonthlyIncome", hue="Attrition", data=df, kind="bar")

# %%
#Employees below the average monthly income are resigning as compared to those above
